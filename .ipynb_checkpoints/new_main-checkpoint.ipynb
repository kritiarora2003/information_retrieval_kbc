# %%
# Import functions from helper python files.

import t5train_code, file_code, pairs_code, model_code
import importlib
from tqdm import tqdm
tqdm.pandas()

import pandas as pd
# Out:
# /home/sjain/anaconda3/lib/python3.11/site-packages/torch/utils/_pytree.py:185: FutureWarning: optree is installed but the version is too old to support PyTorch Dynamo in C++ pytree. C++ pytree support is disabled. Please consider upgrading optree using `python3 -m pip install --upgrade 'optree>=0.13.0'`.
#   warnings.warn(
# /home/sjain/anaconda3/lib/python3.11/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# 2025-10-12 20:14:06.873490: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-12 20:14:06.887715: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-10-12 20:14:06.905830: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-10-12 20:14:06.910846: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-10-12 20:14:06.925405: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-12 20:14:07.900184: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/sjain/anaconda3/lib/python3.11/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(

# %%
importlib.reload(file_code)
from file_code import *

# %%
files = get_files()
# Out:
# Reading raw data from text files. Generating files dataframe.
# Read-in train files: 100%|████████████████| 7350/7350 [00:05<00:00, 1398.10it/s]
# Read-in test files: 100%|██████████████████| 2159/2159 [00:02<00:00, 804.86it/s]
# Returning "files" df.

# %%
files_all = files

# %%
row_true = files_all[files_all['query'] == True].sample(n=1)
row_false = files_all[files_all['query'] == False].sample(n=1)

# Combine them
files = pd.concat([row_true, row_false])
files
# Out:
#      filename    set  query cases  \
# 7174   032547   test   True    []
# 13     085437  train  False    []
#
#                                                    text
# 7174  Background\n[1]\n: This is an action in which ...
# 13    -\n--I. NATURE OF THE ACTION\n7\n--III. CONTEX...

# %%
add_paragraphs(files)
files
# Out:
# Reading text from files. Extracting paragraphs based on regex pattern.
# Extracting all paragraphs: 100%|██████████| 9289/9289 [00:09<00:00, 1001.15it/s]
# Updated "files" df has with "paragraphs".
#      filename    set  query                                             cases  \
# 0      059961  train  False                                                []
# 1      058794  train  False                                                []
# 2      057680  train  False                                                []
# 3      075584  train   True  [067672.txt, 019050.txt, 095238.txt, 047989.txt]
# 4      085456  train  False                                                []
# ...       ...    ...    ...                                               ...
# 9284   076100   test  False                                                []
# 9285   035730   test  False                                                []
# 9286   005193   test  False                                                []
# 9287   053188   test   True                                                []
# 9288   072311   test  False                                                []
#
#                                                    text  \
# 0     Indexed As: Canada (Minister of Citizenship an...
# 1     <FRAGMENT_SUPPRESSED>  (TD)\nMLB headnote and ...
# 2     [1]\n: This is a judicial review application o...
# 3     Introduction\n[1]\n[Translation]: It is well e...
# 4     Summary:\nThe Immigration Appeal Division of t...
# ...                                                 ...
# 9284  [1]\n: This application for judicial review co...
# 9285  Federal Court\nMactavish, J.\nFebruary 20, 200...
# 9286  [1]\n: This is an application for judicial rev...
# 9287  Federal Court\nFebruary 16, 2007.\nKingsley I....
# 9288  Reasons For Judgment\n[1]\n[Original]: This ac...
#
#                                              paragraphs
# 0     [[1] Tremblay-Lamer, J. : This is an appeal by...
# 1     [[2] For the purposes of this motion, the fact...
# 2     [[1] : This is a judicial review application o...
# 3     [[1] [Translation]: It is well established in ...
# 4     [[1] : This is an application pursuant to subs...
# ...                                                 ...
# 9284  [[1] : This application for judicial review co...
# 9285  [[1] Mactavish, J. : Sarfraz Hussain, his wife...
# 9286  [[1] : This is an application for judicial rev...
# 9287  [[1] : This is an application pursuant to subs...
# 9288  [[1] [Original]: This action in patent infring...
#
# [9289 rows x 6 columns]

# %%
get_paragraphs_formatted(files)
files
# Out:
# Getting formatted paragraphs of length < 250 words.
# Getting formatted paragraphs: 100%|████████| 9289/9289 [00:11<00:00, 830.01it/s]
# Added formatted paragraphs to "files" df in "paragraphs_formatted".
#      filename    set  query                                             cases  \
# 0      059961  train  False                                                []
# 1      058794  train  False                                                []
# 2      057680  train  False                                                []
# 3      075584  train   True  [067672.txt, 019050.txt, 095238.txt, 047989.txt]
# 4      085456  train  False                                                []
# ...       ...    ...    ...                                               ...
# 9284   076100   test  False                                                []
# 9285   035730   test  False                                                []
# 9286   005193   test  False                                                []
# 9287   053188   test   True                                                []
# 9288   072311   test  False                                                []
#
#                                                    text  \
# 0     Indexed As: Canada (Minister of Citizenship an...
# 1     <FRAGMENT_SUPPRESSED>  (TD)\nMLB headnote and ...
# 2     [1]\n: This is a judicial review application o...
# 3     Introduction\n[1]\n[Translation]: It is well e...
# 4     Summary:\nThe Immigration Appeal Division of t...
# ...                                                 ...
# 9284  [1]\n: This application for judicial review co...
# 9285  Federal Court\nMactavish, J.\nFebruary 20, 200...
# 9286  [1]\n: This is an application for judicial rev...
# 9287  Federal Court\nFebruary 16, 2007.\nKingsley I....
# 9288  Reasons For Judgment\n[1]\n[Original]: This ac...
#
#                                              paragraphs  \
# 0     [[1] Tremblay-Lamer, J. : This is an appeal by...
# 1     [[2] For the purposes of this motion, the fact...
# 2     [[1] : This is a judicial review application o...
# 3     [[1] [Translation]: It is well established in ...
# 4     [[1] : This is an application pursuant to subs...
# ...                                                 ...
# 9284  [[1] : This application for judicial review co...
# 9285  [[1] Mactavish, J. : Sarfraz Hussain, his wife...
# 9286  [[1] : This is an application for judicial rev...
# 9287  [[1] : This is an application pursuant to subs...
# 9288  [[1] [Original]: This action in patent infring...
#
#                                    paragraphs_formatted
# 0     [Tremblay-Lamer, J. : This is an appeal by the...
# 1     [For the purposes of this motion, the facts se...
# 2     [: This is a judicial review application of th...
# 3     [[Translation]: It is well established in the ...
# 4     [: This is an application pursuant to subsecti...
# ...                                                 ...
# 9284  [: This application for judicial review concer...
# 9285  [Mactavish, J. : Sarfraz Hussain, his wife and...
# 9286  [: This is an application for judicial review ...
# 9287  [: This is an application pursuant to subsecti...
# 9288  [[Original]: This action in patent infringemen...
#
# [9289 rows x 7 columns]

# %%
add_suppressed_sections(files)
files
# Out:
# Using regex and spacy (for long paragraphs) to extract and modify suppressed sections from paragraphs:
# Extracting suppressed sections from paragraphs: 100%|█| 9289/9289 [11:27<00:00,
# Added suppressed sections to "suppressed_sections" field.
#      filename    set  query                                             cases  \
# 0      059961  train  False                                                []
# 1      058794  train  False                                                []
# 2      057680  train  False                                                []
# 3      075584  train   True  [067672.txt, 019050.txt, 095238.txt, 047989.txt]
# 4      085456  train  False                                                []
# ...       ...    ...    ...                                               ...
# 9284   076100   test  False                                                []
# 9285   035730   test  False                                                []
# 9286   005193   test  False                                                []
# 9287   053188   test   True                                                []
# 9288   072311   test  False                                                []
#
#                                                    text  \
# 0     Indexed As: Canada (Minister of Citizenship an...
# 1     <FRAGMENT_SUPPRESSED>  (TD)\nMLB headnote and ...
# 2     [1]\n: This is a judicial review application o...
# 3     Introduction\n[1]\n[Translation]: It is well e...
# 4     Summary:\nThe Immigration Appeal Division of t...
# ...                                                 ...
# 9284  [1]\n: This application for judicial review co...
# 9285  Federal Court\nMactavish, J.\nFebruary 20, 200...
# 9286  [1]\n: This is an application for judicial rev...
# 9287  Federal Court\nFebruary 16, 2007.\nKingsley I....
# 9288  Reasons For Judgment\n[1]\n[Original]: This ac...
#
#                                              paragraphs  \
# 0     [[1] Tremblay-Lamer, J. : This is an appeal by...
# 1     [[2] For the purposes of this motion, the fact...
# 2     [[1] : This is a judicial review application o...
# 3     [[1] [Translation]: It is well established in ...
# 4     [[1] : This is an application pursuant to subs...
# ...                                                 ...
# 9284  [[1] : This application for judicial review co...
# 9285  [[1] Mactavish, J. : Sarfraz Hussain, his wife...
# 9286  [[1] : This is an application for judicial rev...
# 9287  [[1] : This is an application pursuant to subs...
# 9288  [[1] [Original]: This action in patent infring...
#
#                                    paragraphs_formatted  \
# 0     [Tremblay-Lamer, J. : This is an appeal by the...
# 1     [For the purposes of this motion, the facts se...
# 2     [: This is a judicial review application of th...
# 3     [[Translation]: It is well established in the ...
# 4     [: This is an application pursuant to subsecti...
# ...                                                 ...
# 9284  [: This application for judicial review concer...
# 9285  [Mactavish, J. : Sarfraz Hussain, his wife and...
# 9286  [: This is an application for judicial review ...
# 9287  [: This is an application pursuant to subsecti...
# 9288  [[Original]: This action in patent infringemen...
#
#                                     suppressed_sections
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [[1] [Translation]: It is well established in ...
# 4                                                    []
# ...                                                 ...
# 9284                                                 []
# 9285                                                 []
# 9286                                                 []
# 9287  [[9] The Board found it speculative that the a...
# 9288                                                 []
#
# [9289 rows x 8 columns]

# %%
import re

def clean_supressed_section_list(section_list):
    """
    Cleans each string in supressed_section list individually:
    - Removes citation numbers like [1], [2], etc.
    - Removes uppercase 'REFERENCE' and 'TARGETCASE' (with or without <>)
    - Removes 'supra'
    - Removes empty parentheses and extra punctuation
    - Strips extra spaces
    - Keeps only unique sentences per section
    """
    if not section_list:
        return []
    
    if not isinstance(section_list, list):
        section_list = [section_list]
    
    cleaned_list = []
    for text in section_list:
        # Remove citation numbers like [1], [23], etc.
        text = re.sub(r"\[\d+\]", "", text)
        # Remove uppercase REFERENCE/TARGETCASE (with or without < >)
        text = re.sub(r"<*REFERENCE>*|<*TARGETCASE>*", "", text)
        # Remove 'supra'
        text = re.sub(r"\bsupra\b", "", text, flags=re.IGNORECASE)
        # Remove empty parentheses
        text = re.sub(r"\(\s*\)", "", text)
        # Remove multiple punctuation marks and extra spaces
        text = re.sub(r"[;,\s]{2,}", " ", text)
        text = re.sub(r"\s+", " ", text)
        # Strip leading/trailing spaces
        text = text.strip()
        if text:  # only keep non-empty strings
            cleaned_list.append(text)
    
    # Remove duplicates within this section while preserving order
    seen = set()
    unique_list = []
    for item in cleaned_list:
        if item not in seen:
            seen.add(item)
            unique_list.append(item)
    
    return unique_list

    
files["propositions"] = files["suppressed_sections"].apply(clean_supressed_section_list)
files
# Out:
#      filename    set  query                                             cases  \
# 0      059961  train  False                                                []
# 1      058794  train  False                                                []
# 2      057680  train  False                                                []
# 3      075584  train   True  [067672.txt, 019050.txt, 095238.txt, 047989.txt]
# 4      085456  train  False                                                []
# ...       ...    ...    ...                                               ...
# 9284   076100   test  False                                                []
# 9285   035730   test  False                                                []
# 9286   005193   test  False                                                []
# 9287   053188   test   True                                                []
# 9288   072311   test  False                                                []
#
#                                                    text  \
# 0     Indexed As: Canada (Minister of Citizenship an...
# 1     <FRAGMENT_SUPPRESSED>  (TD)\nMLB headnote and ...
# 2     [1]\n: This is a judicial review application o...
# 3     Introduction\n[1]\n[Translation]: It is well e...
# 4     Summary:\nThe Immigration Appeal Division of t...
# ...                                                 ...
# 9284  [1]\n: This application for judicial review co...
# 9285  Federal Court\nMactavish, J.\nFebruary 20, 200...
# 9286  [1]\n: This is an application for judicial rev...
# 9287  Federal Court\nFebruary 16, 2007.\nKingsley I....
# 9288  Reasons For Judgment\n[1]\n[Original]: This ac...
#
#                                              paragraphs  \
# 0     [[1] Tremblay-Lamer, J. : This is an appeal by...
# 1     [[2] For the purposes of this motion, the fact...
# 2     [[1] : This is a judicial review application o...
# 3     [[1] [Translation]: It is well established in ...
# 4     [[1] : This is an application pursuant to subs...
# ...                                                 ...
# 9284  [[1] : This application for judicial review co...
# 9285  [[1] Mactavish, J. : Sarfraz Hussain, his wife...
# 9286  [[1] : This is an application for judicial rev...
# 9287  [[1] : This is an application pursuant to subs...
# 9288  [[1] [Original]: This action in patent infring...
#
#                                    paragraphs_formatted  \
# 0     [Tremblay-Lamer, J. : This is an appeal by the...
# 1     [For the purposes of this motion, the facts se...
# 2     [: This is a judicial review application of th...
# 3     [[Translation]: It is well established in the ...
# 4     [: This is an application pursuant to subsecti...
# ...                                                 ...
# 9284  [: This application for judicial review concer...
# 9285  [Mactavish, J. : Sarfraz Hussain, his wife and...
# 9286  [: This is an application for judicial review ...
# 9287  [: This is an application pursuant to subsecti...
# 9288  [[Original]: This action in patent infringemen...
#
#                                     suppressed_sections  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [[1] [Translation]: It is well established in ...
# 4                                                    []
# ...                                                 ...
# 9284                                                 []
# 9285                                                 []
# 9286                                                 []
# 9287  [[9] The Board found it speculative that the a...
# 9288                                                 []
#
#                                            propositions
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [[Translation]: It is well established in the ...
# 4                                                    []
# ...                                                 ...
# 9284                                                 []
# 9285                                                 []
# 9286                                                 []
# 9287  [The Board found it speculative that the appli...
# 9288                                                 []
#
# [9289 rows x 9 columns]

# %%
files["propositions_en"] = files["propositions"]
files
# Out:
#      filename    set  query                                             cases  \
# 0      059961  train  False                                                []
# 1      058794  train  False                                                []
# 2      057680  train  False                                                []
# 3      075584  train   True  [067672.txt, 019050.txt, 095238.txt, 047989.txt]
# 4      085456  train  False                                                []
# ...       ...    ...    ...                                               ...
# 9284   076100   test  False                                                []
# 9285   035730   test  False                                                []
# 9286   005193   test  False                                                []
# 9287   053188   test   True                                                []
# 9288   072311   test  False                                                []
#
#                                                    text  \
# 0     Indexed As: Canada (Minister of Citizenship an...
# 1     <FRAGMENT_SUPPRESSED>  (TD)\nMLB headnote and ...
# 2     [1]\n: This is a judicial review application o...
# 3     Introduction\n[1]\n[Translation]: It is well e...
# 4     Summary:\nThe Immigration Appeal Division of t...
# ...                                                 ...
# 9284  [1]\n: This application for judicial review co...
# 9285  Federal Court\nMactavish, J.\nFebruary 20, 200...
# 9286  [1]\n: This is an application for judicial rev...
# 9287  Federal Court\nFebruary 16, 2007.\nKingsley I....
# 9288  Reasons For Judgment\n[1]\n[Original]: This ac...
#
#                                              paragraphs  \
# 0     [[1] Tremblay-Lamer, J. : This is an appeal by...
# 1     [[2] For the purposes of this motion, the fact...
# 2     [[1] : This is a judicial review application o...
# 3     [[1] [Translation]: It is well established in ...
# 4     [[1] : This is an application pursuant to subs...
# ...                                                 ...
# 9284  [[1] : This application for judicial review co...
# 9285  [[1] Mactavish, J. : Sarfraz Hussain, his wife...
# 9286  [[1] : This is an application for judicial rev...
# 9287  [[1] : This is an application pursuant to subs...
# 9288  [[1] [Original]: This action in patent infring...
#
#                                    paragraphs_formatted  \
# 0     [Tremblay-Lamer, J. : This is an appeal by the...
# 1     [For the purposes of this motion, the facts se...
# 2     [: This is a judicial review application of th...
# 3     [[Translation]: It is well established in the ...
# 4     [: This is an application pursuant to subsecti...
# ...                                                 ...
# 9284  [: This application for judicial review concer...
# 9285  [Mactavish, J. : Sarfraz Hussain, his wife and...
# 9286  [: This is an application for judicial review ...
# 9287  [: This is an application pursuant to subsecti...
# 9288  [[Original]: This action in patent infringemen...
#
#                                     suppressed_sections  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [[1] [Translation]: It is well established in ...
# 4                                                    []
# ...                                                 ...
# 9284                                                 []
# 9285                                                 []
# 9286                                                 []
# 9287  [[9] The Board found it speculative that the a...
# 9288                                                 []
#
#                                            propositions  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [[Translation]: It is well established in the ...
# 4                                                    []
# ...                                                 ...
# 9284                                                 []
# 9285                                                 []
# 9286                                                 []
# 9287  [The Board found it speculative that the appli...
# 9288                                                 []
#
#                                         propositions_en
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [[Translation]: It is well established in the ...
# 4                                                    []
# ...                                                 ...
# 9284                                                 []
# 9285                                                 []
# 9286                                                 []
# 9287  [The Board found it speculative that the appli...
# 9288                                                 []
#
# [9289 rows x 10 columns]

# %%
add_sentences(files)
# Out:
# Using spacy to extract sentences of char length > 25 from paragraphs:
# Extracting sentences from paragraphs: 100%|█| 9289/9289 [1:16:58<00:00,  2.01it/
# Added lists of sentences to "sentences".

# %%
for s in files['sentences'].iloc[:2]:
    print(len(s))   # how many sentences per row?
# Out:
# 65
# 48

# %%
files
# Out:
#      filename    set  query                                             cases  \
# 0      059961  train  False                                                []
# 1      058794  train  False                                                []
# 2      057680  train  False                                                []
# 3      075584  train   True  [067672.txt, 019050.txt, 095238.txt, 047989.txt]
# 4      085456  train  False                                                []
# ...       ...    ...    ...                                               ...
# 9284   076100   test  False                                                []
# 9285   035730   test  False                                                []
# 9286   005193   test  False                                                []
# 9287   053188   test   True                                                []
# 9288   072311   test  False                                                []
#
#                                                    text  \
# 0     Indexed As: Canada (Minister of Citizenship an...
# 1     <FRAGMENT_SUPPRESSED>  (TD)\nMLB headnote and ...
# 2     [1]\n: This is a judicial review application o...
# 3     Introduction\n[1]\n[Translation]: It is well e...
# 4     Summary:\nThe Immigration Appeal Division of t...
# ...                                                 ...
# 9284  [1]\n: This application for judicial review co...
# 9285  Federal Court\nMactavish, J.\nFebruary 20, 200...
# 9286  [1]\n: This is an application for judicial rev...
# 9287  Federal Court\nFebruary 16, 2007.\nKingsley I....
# 9288  Reasons For Judgment\n[1]\n[Original]: This ac...
#
#                                              paragraphs  \
# 0     [[1] Tremblay-Lamer, J. : This is an appeal by...
# 1     [[2] For the purposes of this motion, the fact...
# 2     [[1] : This is a judicial review application o...
# 3     [[1] [Translation]: It is well established in ...
# 4     [[1] : This is an application pursuant to subs...
# ...                                                 ...
# 9284  [[1] : This application for judicial review co...
# 9285  [[1] Mactavish, J. : Sarfraz Hussain, his wife...
# 9286  [[1] : This is an application for judicial rev...
# 9287  [[1] : This is an application pursuant to subs...
# 9288  [[1] [Original]: This action in patent infring...
#
#                                    paragraphs_formatted  \
# 0     [Tremblay-Lamer, J. : This is an appeal by the...
# 1     [For the purposes of this motion, the facts se...
# 2     [: This is a judicial review application of th...
# 3     [[Translation]: It is well established in the ...
# 4     [: This is an application pursuant to subsecti...
# ...                                                 ...
# 9284  [: This application for judicial review concer...
# 9285  [Mactavish, J. : Sarfraz Hussain, his wife and...
# 9286  [: This is an application for judicial review ...
# 9287  [: This is an application pursuant to subsecti...
# 9288  [[Original]: This action in patent infringemen...
#
#                                     suppressed_sections  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [[1] [Translation]: It is well established in ...
# 4                                                    []
# ...                                                 ...
# 9284                                                 []
# 9285                                                 []
# 9286                                                 []
# 9287  [[9] The Board found it speculative that the a...
# 9288                                                 []
#
#                                            propositions  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [[Translation]: It is well established in the ...
# 4                                                    []
# ...                                                 ...
# 9284                                                 []
# 9285                                                 []
# 9286                                                 []
# 9287  [The Board found it speculative that the appli...
# 9288                                                 []
#
#                                         propositions_en  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [[Translation]: It is well established in the ...
# 4                                                    []
# ...                                                 ...
# 9284                                                 []
# 9285                                                 []
# 9286                                                 []
# 9287  [The Board found it speculative that the appli...
# 9288                                                 []
#
#                                               sentences
# 0     [This is an appeal by the Minister of Citizens...
# 1     [For the purposes of this motion, the facts se...
# 2     [: This is a judicial review application of th...
# 3     [[Translation]: It is well established in the ...
# 4     [: This is an application pursuant to subsecti...
# ...                                                 ...
# 9284  [: This application for judicial review concer...
# 9285  [Mactavish, J. : Sarfraz Hussain, his wife and...
# 9286  [: This is an application for judicial review ...
# 9287  [: This is an application pursuant to subsecti...
# 9288  [[Original]: This action in patent infringemen...
#
# [9289 rows x 11 columns]

# %%
files["sentences_en"] = files["sentences"]
files
# Out:
#      filename    set  query                                             cases  \
# 0      059961  train  False                                                []
# 1      058794  train  False                                                []
# 2      057680  train  False                                                []
# 3      075584  train   True  [067672.txt, 019050.txt, 095238.txt, 047989.txt]
# 4      085456  train  False                                                []
# ...       ...    ...    ...                                               ...
# 9284   076100   test  False                                                []
# 9285   035730   test  False                                                []
# 9286   005193   test  False                                                []
# 9287   053188   test   True                                                []
# 9288   072311   test  False                                                []
#
#                                                    text  \
# 0     Indexed As: Canada (Minister of Citizenship an...
# 1     <FRAGMENT_SUPPRESSED>  (TD)\nMLB headnote and ...
# 2     [1]\n: This is a judicial review application o...
# 3     Introduction\n[1]\n[Translation]: It is well e...
# 4     Summary:\nThe Immigration Appeal Division of t...
# ...                                                 ...
# 9284  [1]\n: This application for judicial review co...
# 9285  Federal Court\nMactavish, J.\nFebruary 20, 200...
# 9286  [1]\n: This is an application for judicial rev...
# 9287  Federal Court\nFebruary 16, 2007.\nKingsley I....
# 9288  Reasons For Judgment\n[1]\n[Original]: This ac...
#
#                                              paragraphs  \
# 0     [[1] Tremblay-Lamer, J. : This is an appeal by...
# 1     [[2] For the purposes of this motion, the fact...
# 2     [[1] : This is a judicial review application o...
# 3     [[1] [Translation]: It is well established in ...
# 4     [[1] : This is an application pursuant to subs...
# ...                                                 ...
# 9284  [[1] : This application for judicial review co...
# 9285  [[1] Mactavish, J. : Sarfraz Hussain, his wife...
# 9286  [[1] : This is an application for judicial rev...
# 9287  [[1] : This is an application pursuant to subs...
# 9288  [[1] [Original]: This action in patent infring...
#
#                                    paragraphs_formatted  \
# 0     [Tremblay-Lamer, J. : This is an appeal by the...
# 1     [For the purposes of this motion, the facts se...
# 2     [: This is a judicial review application of th...
# 3     [[Translation]: It is well established in the ...
# 4     [: This is an application pursuant to subsecti...
# ...                                                 ...
# 9284  [: This application for judicial review concer...
# 9285  [Mactavish, J. : Sarfraz Hussain, his wife and...
# 9286  [: This is an application for judicial review ...
# 9287  [: This is an application pursuant to subsecti...
# 9288  [[Original]: This action in patent infringemen...
#
#                                     suppressed_sections  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [[1] [Translation]: It is well established in ...
# 4                                                    []
# ...                                                 ...
# 9284                                                 []
# 9285                                                 []
# 9286                                                 []
# 9287  [[9] The Board found it speculative that the a...
# 9288                                                 []
#
#                                            propositions  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [[Translation]: It is well established in the ...
# 4                                                    []
# ...                                                 ...
# 9284                                                 []
# 9285                                                 []
# 9286                                                 []
# 9287  [The Board found it speculative that the appli...
# 9288                                                 []
#
#                                         propositions_en  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [[Translation]: It is well established in the ...
# 4                                                    []
# ...                                                 ...
# 9284                                                 []
# 9285                                                 []
# 9286                                                 []
# 9287  [The Board found it speculative that the appli...
# 9288                                                 []
#
#                                               sentences  \
# 0     [This is an appeal by the Minister of Citizens...
# 1     [For the purposes of this motion, the facts se...
# 2     [: This is a judicial review application of th...
# 3     [[Translation]: It is well established in the ...
# 4     [: This is an application pursuant to subsecti...
# ...                                                 ...
# 9284  [: This application for judicial review concer...
# 9285  [Mactavish, J. : Sarfraz Hussain, his wife and...
# 9286  [: This is an application for judicial review ...
# 9287  [: This is an application pursuant to subsecti...
# 9288  [[Original]: This action in patent infringemen...
#
#                                            sentences_en
# 0     [This is an appeal by the Minister of Citizens...
# 1     [For the purposes of this motion, the facts se...
# 2     [: This is a judicial review application of th...
# 3     [[Translation]: It is well established in the ...
# 4     [: This is an application pursuant to subsecti...
# ...                                                 ...
# 9284  [: This application for judicial review concer...
# 9285  [Mactavish, J. : Sarfraz Hussain, his wife and...
# 9286  [: This is an application for judicial review ...
# 9287  [: This is an application pursuant to subsecti...
# 9288  [[Original]: This action in patent infringemen...
#
# [9289 rows x 12 columns]

# %%
add_quotes(files)
add_entities(files)
add_strings_sets(files)
files
# Out:
# Using regex to extract quotations from suppressed sections:
# Extracting quotes from suppressed sections:: 100%|█| 9289/9289 [00:00<00:00, 134
# Added quotes to the "quotes" field for query cases.
# Using spacy to extract noun entities, from English sentences:
# Extracting entities from english sentences: 100%|█| 9289/9289 [49:16<00:00,  3.1
# Added entity strings to "entity_string" and entities as sets to "entity_set".
# Extracting case word strings (for tfidf) and sets (for case jaccard):
# Extracting case string and sets from sentences_en:: 100%|█| 9289/9289 [02:06<00:
# Added case strings and sets.
#      filename    set  query                                             cases  \
# 0      059961  train  False                                                []
# 1      058794  train  False                                                []
# 2      057680  train  False                                                []
# 3      075584  train   True  [067672.txt, 019050.txt, 095238.txt, 047989.txt]
# 4      085456  train  False                                                []
# ...       ...    ...    ...                                               ...
# 9284   076100   test  False                                                []
# 9285   035730   test  False                                                []
# 9286   005193   test  False                                                []
# 9287   053188   test   True                                                []
# 9288   072311   test  False                                                []
#
#                                                    text  \
# 0     Indexed As: Canada (Minister of Citizenship an...
# 1     <FRAGMENT_SUPPRESSED>  (TD)\nMLB headnote and ...
# 2     [1]\n: This is a judicial review application o...
# 3     Introduction\n[1]\n[Translation]: It is well e...
# 4     Summary:\nThe Immigration Appeal Division of t...
# ...                                                 ...
# 9284  [1]\n: This application for judicial review co...
# 9285  Federal Court\nMactavish, J.\nFebruary 20, 200...
# 9286  [1]\n: This is an application for judicial rev...
# 9287  Federal Court\nFebruary 16, 2007.\nKingsley I....
# 9288  Reasons For Judgment\n[1]\n[Original]: This ac...
#
#                                              paragraphs  \
# 0     [[1] Tremblay-Lamer, J. : This is an appeal by...
# 1     [[2] For the purposes of this motion, the fact...
# 2     [[1] : This is a judicial review application o...
# 3     [[1] [Translation]: It is well established in ...
# 4     [[1] : This is an application pursuant to subs...
# ...                                                 ...
# 9284  [[1] : This application for judicial review co...
# 9285  [[1] Mactavish, J. : Sarfraz Hussain, his wife...
# 9286  [[1] : This is an application for judicial rev...
# 9287  [[1] : This is an application pursuant to subs...
# 9288  [[1] [Original]: This action in patent infring...
#
#                                    paragraphs_formatted  \
# 0     [Tremblay-Lamer, J. : This is an appeal by the...
# 1     [For the purposes of this motion, the facts se...
# 2     [: This is a judicial review application of th...
# 3     [[Translation]: It is well established in the ...
# 4     [: This is an application pursuant to subsecti...
# ...                                                 ...
# 9284  [: This application for judicial review concer...
# 9285  [Mactavish, J. : Sarfraz Hussain, his wife and...
# 9286  [: This is an application for judicial review ...
# 9287  [: This is an application pursuant to subsecti...
# 9288  [[Original]: This action in patent infringemen...
#
#                                     suppressed_sections  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [[1] [Translation]: It is well established in ...
# 4                                                    []
# ...                                                 ...
# 9284                                                 []
# 9285                                                 []
# 9286                                                 []
# 9287  [[9] The Board found it speculative that the a...
# 9288                                                 []
#
#                                            propositions  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [[Translation]: It is well established in the ...
# 4                                                    []
# ...                                                 ...
# 9284                                                 []
# 9285                                                 []
# 9286                                                 []
# 9287  [The Board found it speculative that the appli...
# 9288                                                 []
#
#                                         propositions_en  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [[Translation]: It is well established in the ...
# 4                                                    []
# ...                                                 ...
# 9284                                                 []
# 9285                                                 []
# 9286                                                 []
# 9287  [The Board found it speculative that the appli...
# 9288                                                 []
#
#                                               sentences  \
# 0     [This is an appeal by the Minister of Citizens...
# 1     [For the purposes of this motion, the facts se...
# 2     [: This is a judicial review application of th...
# 3     [[Translation]: It is well established in the ...
# 4     [: This is an application pursuant to subsecti...
# ...                                                 ...
# 9284  [: This application for judicial review concer...
# 9285  [Mactavish, J. : Sarfraz Hussain, his wife and...
# 9286  [: This is an application for judicial review ...
# 9287  [: This is an application pursuant to subsecti...
# 9288  [[Original]: This action in patent infringemen...
#
#                                            sentences_en  \
# 0     [This is an appeal by the Minister of Citizens...
# 1     [For the purposes of this motion, the facts se...
# 2     [: This is a judicial review application of th...
# 3     [[Translation]: It is well established in the ...
# 4     [: This is an application pursuant to subsecti...
# ...                                                 ...
# 9284  [: This application for judicial review concer...
# 9285  [Mactavish, J. : Sarfraz Hussain, his wife and...
# 9286  [: This is an application for judicial review ...
# 9287  [: This is an application pursuant to subsecti...
# 9288  [[Original]: This action in patent infringemen...
#
#                                                  quotes  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [range of possible acceptable outcomes which a...
# 4                                                    []
# ...                                                 ...
# 9284                                                 []
# 9285                                                 []
# 9286                                                 []
# 9287                                                 []
# 9288                                                 []
#
#                                           entity_string  \
# 0     citizenshipimmigration citizenshipact canadian...
# 1     francoeur canadian unitedstates unitedstates u...
# 2     citizenshipimmigration immigrationrefugeeprote...
# 3     court section immigrationrefugeeprotectionregu...
# 4     immigrationrefugeeprotection immigrationappeal...
# ...                                                 ...
# 9284  refugeeappealdivision immigrationrefugeeboard ...
# 9285  pakistan shiamuslims sunnimuslims sahaba pakis...
# 9286  prra immigrationrefugeeprotectionact srilanka ...
# 9287  immigrationrefugeeprotectionact irpa refugeepr...
# 9288  montréal québec ontario ontario québec  québec...
#
#                                              entity_set  \
# 0     {hongkong, unitedstates, citizenshipimmigratio...
# 1     {, unitedstates, columbia, leasing, honourable...
# 2     {citizenshipimmigration, burundi, burundian, r...
# 3     {, caq, tunisia, municipalcourtmontreal, spous...
# 4     {, parliament, controlleddrugact, supremecourt...
# ...                                                 ...
# 9284  {parliament, citizenshipimmigrationjasonkenney...
# 9285  {, shiamuslims, sahaba, convention, citizenshi...
# 9286  {, pta, uned, refugee, pcdo, canadian, citizen...
# 9287  {, zimbabweafricannational, unitedkingdom, con...
# 9288  {, applicationinterlocutoryinjunction, pisasto...
#
#                                     sentences_en_string  \
# 0     appeal minist citizenship immigr minist pursua...
# 1     purpos motion fact set plead deem admit true r...
# 2     judici review applic decis deleg minist citize...
# 3     translat establish case law court specif crite...
# 4     applic pursuant subsect immigr refuge protect ...
# ...                                                 ...
# 9284  applic judici review concern power duti newli ...
# 9285  mactavish j sarfraz hussain wife adult son cit...
# 9286  applic judici review decis date decemb s morga...
# 9287  applic pursuant subsect immigr refuge protect ...
# 9288  origin action patent infring commenc final hea...
#
#                                        sentences_en_set
# 0     {imprecis, special, submiss, spars, came, clie...
# 1     {assert, circumst, lack, submiss, ma, set, can...
# 2     {claimant, grant, highli, conflict, situat, ga...
# 3     {defens, lack, tunisia, specif, came, testimon...
# 4     {apart, dealt, distinct, grant, extens, retent...
# ...                                                 ...
# 9284  {claimant, quasijudici, interpret, grant, dese...
# 9285  {claimant, situat, treatment, file, danger, so...
# 9286  {claimant, pelleti, apart, global, interpret, ...
# 9287  {claimant, interpret, suppress, misconstru, re...
# 9288  {apart, interpret, offset, slightli, instabl, ...
#
# [9289 rows x 17 columns]

# %%
add_set_lists(files)
add_judge_name(files)
add_year(files)
# Out:
# Extracting set lists:
# Extracting set list sentences_en:: 100%|████| 9289/9289 [02:21<00:00, 65.66it/s]
# Extracting set list paragraphs_formatted::  39%|▍| 3582/9289 [00:36<01:00, 94.55

# %%
files

# %%
get_embeddings(files)
files.to_csv('embeddings_new_all.csv', index=False)
files
